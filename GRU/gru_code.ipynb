# %%
#maotai的GRU数据预测
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dropout, Dense, GRU
import matplotlib.pyplot as plt
import os
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math

maotai = pd.read_csv('./SH600519.csv')
training_set = maotai.iloc[0:5335 - 300, 2:3].values  # 前(2426-300=2126)天的开盘价作为训练集,表格从0开始计数，2:3 是提取[2:3)列，前闭后开,故提取出C列开盘价
test_set = maotai.iloc[5335 - 300:, 2:3].values  # 后300天的开盘价作为测试集

#归一化
sc = MinMaxScaler(feature_range=(0, 1))  # 定义归一化：归一化到(0，1)之间
training_set_scaled = sc.fit_transform(training_set)  # 求得训练集的最大值，最小值这些训练集固有的属性，并在训练集上进行归一化
test_set_scaled = sc.transform(test_set) 

#创建时序数据，用前时刻数据预测后面的数据
def create_dataset(dataset, time_step=60):  #适用于二维度的数据
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		x = dataset[i:(i+time_step)]  
		y = dataset[i:(i+time_step)]
		dataX.append(x)
		dataY.append(dataset[i + time_step, 0])
	return np.array(dataX), np.array(dataY)

train_x, train_y = create_dataset(training_set_scaled)
test_x, test_y = create_dataset(test_set_scaled)

model = tf.keras.Sequential([
    GRU(80, return_sequences=True),
    Dropout(0.2),
    GRU(100),
    Dropout(0.2),
    Dense(1)
])

model.compile(optimizer=tf.keras.optimizers.Adam(0.001),
              loss='mean_squared_error')  # 损失函数用均方误差
# 该应用只观测loss数值，不观测准确率，所以删去metrics选项，一会在每个epoch迭代显示时只显示loss值
checkpoint_save_path = "./GRUcheckpoint/GRUstock.ckpt"
if os.path.exists(checkpoint_save_path + '.index'):
    print('-------------load the model-----------------')
    model.load_weights(checkpoint_save_path)
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_save_path,
                                                 save_weights_only=True,
                                                 save_best_only=True,
                                                 monitor='val_loss')
history = model.fit(train_x, train_y, batch_size=64, epochs=100, validation_data=(test_x, test_y), validation_freq=1,
                    callbacks=[cp_callback])
loss = history.history['loss']
val_loss = history.history['val_loss']
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
# Out:
# -------------load the model-----------------
# Epoch 1/100
# 78/78 [==============================] - 7s 61ms/step - loss: 2.4908e-04 - val_loss: 1.2629e-04
# Epoch 2/100
# 78/78 [==============================] - 4s 57ms/step - loss: 2.6334e-04 - val_loss: 1.7325e-04
# Epoch 3/100
# 78/78 [==============================] - 4s 55ms/step - loss: 2.6747e-04 - val_loss: 5.2077e-04
# Epoch 4/100
# 78/78 [==============================] - 4s 54ms/step - loss: 2.4951e-04 - val_loss: 1.8349e-04
# Epoch 5/100
# 78/78 [==============================] - 4s 56ms/step - loss: 2.4854e-04 - val_loss: 1.7944e-04
# Epoch 6/100
# 78/78 [==============================] - 4s 56ms/step - loss: 2.7160e-04 - val_loss: 1.4554e-04
# Epoch 7/100
# 78/78 [==============================] - 4s 56ms/step - loss: 2.5604e-04 - val_loss: 1.6813e-04
# Epoch 8/100
# 78/78 [==============================] - 4s 57ms/step - loss: 2.6501e-04 - val_loss: 1.7625e-04
# Epoch 9/100
# 78/78 [==============================] - 4s 57ms/step - loss: 2.5725e-04 - val_loss: 1.2606e-04
# Epoch 10/100
# 78/78 [==============================] - 5s 59ms/step - loss: 2.5087e-04 - val_loss: 1.8575e-04
# Epoch 11/100
# 78/78 [==============================] - 4s 57ms/step - loss: 2.5520e-04 - val_loss: 2.0174e-04
# Epoch 12/100
# 78/78 [==============================] - 5s 58ms/step - loss: 2.7203e-04 - val_loss: 1.9821e-04
# Epoch 13/100
# 78/78 [==============================] - 4s 57ms/step - loss: 2.5724e-04 - val_loss: 3.6423e-04
# Epoch 14/100
# 78/78 [==============================] - 4s 56ms/step - loss: 2.4165e-04 - val_loss: 1.3691e-04
# Epoch 15/100
# 78/78 [==============================] - 4s 56ms/step - loss: 2.5882e-04 - val_loss: 1.8085e-04
# Epoch 16/100
# 78/78 [==============================] - 5s 58ms/step - loss: 2.6245e-04 - val_loss: 1.4475e-04
# Epoch 17/100
# 78/78 [==============================] - 4s 56ms/step - loss: 2.5561e-04 - val_loss: 1.2428e-04
# Epoch 18/100
# 78/78 [==============================] - 5s 59ms/step - loss: 2.5585e-04 - val_loss: 5.0988e-04
# Epoch 19/100
# 78/78 [==============================] - 4s 57ms/step - loss: 2.5593e-04 - val_loss: 1.9642e-04
# Epoch 20/100
# 78/78 [==============================] - 4s 56ms/step - loss: 2.2459e-04 - val_loss: 1.7472e-04
# Epoch 21/100
# 78/78 [==============================] - 4s 57ms/step - loss: 2.5624e-04 - val_loss: 2.0248e-04
# Epoch 22/100
# 78/78 [==============================] - 5s 58ms/step - loss: 2.5122e-04 - val_loss: 1.2054e-04
# Epoch 23/100
# 78/78 [==============================] - 5s 58ms/step - loss: 2.5373e-04 - val_loss: 1.2394e-04
# Epoch 24/100
# 78/78 [==============================] - 4s 57ms/step - loss: 2.7327e-04 - val_loss: 2.1015e-04
# Epoch 25/100
# 78/78 [==============================] - 4s 58ms/step - loss: 2.7624e-04 - val_loss: 1.7731e-04
# Epoch 26/100
# 78/78 [==============================] - 4s 58ms/step - loss: 2.3233e-04 - val_loss: 1.4637e-04
# Epoch 27/100
# 78/78 [==============================] - 5s 59ms/step - loss: 2.4590e-04 - val_loss: 1.1994e-04
# Epoch 28/100
# 78/78 [==============================] - 5s 59ms/step - loss: 2.3711e-04 - val_loss: 4.8521e-04
# Epoch 29/100
# 78/78 [==============================] - 5s 58ms/step - loss: 2.3518e-04 - val_loss: 1.9600e-04
# Epoch 30/100
# 78/78 [==============================] - 4s 57ms/step - loss: 2.4391e-04 - val_loss: 2.3084e-04
# Epoch 31/100
# 78/78 [==============================] - 4s 57ms/step - loss: 2.4466e-04 - val_loss: 1.3902e-04
# Epoch 32/100
# 78/78 [==============================] - 5s 59ms/step - loss: 2.4931e-04 - val_loss: 1.7967e-04
# Epoch 33/100
# 78/78 [==============================] - 5s 58ms/step - loss: 2.9878e-04 - val_loss: 1.2784e-04
# Epoch 34/100
# 78/78 [==============================] - 4s 58ms/step - loss: 2.6407e-04 - val_loss: 3.7955e-04
# Epoch 35/100
# 78/78 [==============================] - 4s 56ms/step - loss: 2.5274e-04 - val_loss: 1.2357e-04
# Epoch 36/100
# 78/78 [==============================] - 4s 57ms/step - loss: 2.5199e-04 - val_loss: 1.4034e-04
# Epoch 37/100
# 78/78 [==============================] - 4s 57ms/step - loss: 2.3134e-04 - val_loss: 1.5639e-04
# Epoch 38/100
# 78/78 [==============================] - 4s 56ms/step - loss: 2.6223e-04 - val_loss: 1.4150e-04
# Epoch 39/100
# 78/78 [==============================] - 4s 57ms/step - loss: 2.5269e-04 - val_loss: 1.9888e-04
# Epoch 40/100
# 78/78 [==============================] - 4s 57ms/step - loss: 2.5068e-04 - val_loss: 1.3967e-04
# Epoch 41/100
# 78/78 [==============================] - 4s 56ms/step - loss: 2.2795e-04 - val_loss: 1.6716e-04
# Epoch 42/100
# 78/78 [==============================] - 4s 57ms/step - loss: 2.3857e-04 - val_loss: 5.5323e-04
# Epoch 43/100
# 78/78 [==============================] - 4s 56ms/step - loss: 2.5712e-04 - val_loss: 1.8724e-04
# Epoch 44/100
# 78/78 [==============================] - 4s 56ms/step - loss: 2.4494e-04 - val_loss: 2.5973e-04
# Epoch 45/100
# 78/78 [==============================] - 4s 57ms/step - loss: 2.5947e-04 - val_loss: 2.4958e-04
# Epoch 46/100
# 78/78 [==============================] - 4s 57ms/step - loss: 2.4887e-04 - val_loss: 4.0676e-04
# Epoch 47/100
# 78/78 [==============================] - 4s 56ms/step - loss: 2.5641e-04 - val_loss: 4.5435e-04
# Epoch 48/100
# 78/78 [==============================] - 5s 58ms/step - loss: 2.5724e-04 - val_loss: 2.3294e-04
# Epoch 49/100
# 78/78 [==============================] - 4s 57ms/step - loss: 2.5542e-04 - val_loss: 1.2652e-04
# Epoch 50/100
# 78/78 [==============================] - 4s 56ms/step - loss: 2.3697e-04 - val_loss: 1.2123e-04
# Epoch 51/100
# 78/78 [==============================] - 4s 56ms/step - loss: 2.3381e-04 - val_loss: 1.2255e-04
# Epoch 52/100
# 78/78 [==============================] - 4s 56ms/step - loss: 2.2472e-04 - val_loss: 1.5634e-04
# Epoch 53/100
# 78/78 [==============================] - 4s 56ms/step - loss: 2.3612e-04 - val_loss: 1.2387e-04
# Epoch 54/100
# 78/78 [==============================] - 4s 57ms/step - loss: 2.3861e-04 - val_loss: 1.1800e-04
# Epoch 55/100
# 78/78 [==============================] - 5s 58ms/step - loss: 2.4121e-04 - val_loss: 8.0627e-04
# Epoch 56/100
# 78/78 [==============================] - 5s 58ms/step - loss: 2.4469e-04 - val_loss: 1.6876e-04
# Epoch 57/100
# 78/78 [==============================] - 5s 58ms/step - loss: 2.4072e-04 - val_loss: 2.5082e-04
# Epoch 58/100
# 78/78 [==============================] - 4s 57ms/step - loss: 2.3606e-04 - val_loss: 2.7227e-04
# Epoch 59/100
# 78/78 [==============================] - 5s 58ms/step - loss: 2.2296e-04 - val_loss: 1.7579e-04
# Epoch 60/100
# 78/78 [==============================] - 5s 58ms/step - loss: 2.6257e-04 - val_loss: 2.4539e-04
# Epoch 61/100
# 78/78 [==============================] - 5s 58ms/step - loss: 2.7504e-04 - val_loss: 2.1307e-04
# Epoch 62/100
# 78/78 [==============================] - 5s 58ms/step - loss: 2.5484e-04 - val_loss: 1.4495e-04
# Epoch 63/100
# 78/78 [==============================] - 5s 58ms/step - loss: 2.5420e-04 - val_loss: 1.2831e-04
# Epoch 64/100
# 78/78 [==============================] - 5s 58ms/step - loss: 2.6531e-04 - val_loss: 1.1639e-04
# Epoch 65/100
# 78/78 [==============================] - 5s 58ms/step - loss: 2.6074e-04 - val_loss: 1.6097e-04
# Epoch 66/100
# 78/78 [==============================] - 5s 59ms/step - loss: 2.7920e-04 - val_loss: 1.1864e-04
# Epoch 67/100
# 78/78 [==============================] - 5s 59ms/step - loss: 2.4481e-04 - val_loss: 1.1724e-04
# Epoch 68/100
# 78/78 [==============================] - 5s 58ms/step - loss: 2.3494e-04 - val_loss: 1.6607e-04
# Epoch 69/100
# 78/78 [==============================] - 5s 59ms/step - loss: 2.2054e-04 - val_loss: 2.9458e-04
# Epoch 70/100
# 78/78 [==============================] - 4s 58ms/step - loss: 2.1637e-04 - val_loss: 2.3323e-04
# Epoch 71/100
# 78/78 [==============================] - 5s 58ms/step - loss: 2.7364e-04 - val_loss: 1.2788e-04
# Epoch 72/100
# 78/78 [==============================] - 4s 57ms/step - loss: 2.4204e-04 - val_loss: 1.1687e-04
# Epoch 73/100
# 78/78 [==============================] - 4s 58ms/step - loss: 2.4729e-04 - val_loss: 1.3679e-04
# Epoch 74/100
# 78/78 [==============================] - 4s 57ms/step - loss: 2.3431e-04 - val_loss: 1.3097e-04
# Epoch 75/100
# 78/78 [==============================] - 5s 59ms/step - loss: 2.3939e-04 - val_loss: 1.1835e-04
# Epoch 76/100
# 78/78 [==============================] - 4s 57ms/step - loss: 2.3202e-04 - val_loss: 1.7480e-04
# Epoch 77/100
# 78/78 [==============================] - 4s 56ms/step - loss: 2.2698e-04 - val_loss: 1.4519e-04
# Epoch 78/100
# 78/78 [==============================] - 4s 57ms/step - loss: 2.0013e-04 - val_loss: 2.1724e-04
# Epoch 79/100
# 78/78 [==============================] - 4s 57ms/step - loss: 2.2157e-04 - val_loss: 2.9375e-04
# Epoch 80/100
# 78/78 [==============================] - 5s 59ms/step - loss: 2.3708e-04 - val_loss: 1.9648e-04
# Epoch 81/100
# 78/78 [==============================] - 4s 57ms/step - loss: 2.3187e-04 - val_loss: 4.8916e-04
# Epoch 82/100
# 78/78 [==============================] - 5s 58ms/step - loss: 2.4617e-04 - val_loss: 1.1414e-04
# Epoch 83/100
# 78/78 [==============================] - 5s 59ms/step - loss: 2.4877e-04 - val_loss: 1.1854e-04
# Epoch 84/100
# 78/78 [==============================] - 5s 60ms/step - loss: 2.5782e-04 - val_loss: 1.4006e-04
# Epoch 85/100
# 78/78 [==============================] - 4s 57ms/step - loss: 2.2504e-04 - val_loss: 1.8870e-04
# Epoch 86/100
# 78/78 [==============================] - 5s 58ms/step - loss: 2.3272e-04 - val_loss: 8.9409e-04
# Epoch 87/100
# 78/78 [==============================] - 4s 57ms/step - loss: 2.1977e-04 - val_loss: 1.1088e-04
# Epoch 88/100
# 78/78 [==============================] - 5s 59ms/step - loss: 2.2322e-04 - val_loss: 2.6186e-04
# Epoch 89/100
# 78/78 [==============================] - 5s 58ms/step - loss: 2.3427e-04 - val_loss: 1.4832e-04
# Epoch 90/100
# 78/78 [==============================] - 5s 59ms/step - loss: 2.4089e-04 - val_loss: 2.7124e-04
# Epoch 91/100
# 78/78 [==============================] - 5s 58ms/step - loss: 2.4034e-04 - val_loss: 4.2365e-04
# Epoch 92/100
# 78/78 [==============================] - 5s 58ms/step - loss: 2.3961e-04 - val_loss: 2.2592e-04
# Epoch 93/100
# 78/78 [==============================] - 5s 59ms/step - loss: 2.1798e-04 - val_loss: 2.6468e-04
# Epoch 94/100
# 78/78 [==============================] - 5s 58ms/step - loss: 2.6178e-04 - val_loss: 1.7538e-04
# Epoch 95/100
# 78/78 [==============================] - 5s 58ms/step - loss: 2.1199e-04 - val_loss: 1.4803e-04
# Epoch 96/100
# 78/78 [==============================] - 4s 57ms/step - loss: 2.2862e-04 - val_loss: 1.3083e-04
# Epoch 97/100
# 78/78 [==============================] - 5s 59ms/step - loss: 2.4590e-04 - val_loss: 1.0889e-04
# Epoch 98/100
# 78/78 [==============================] - 5s 59ms/step - loss: 2.0792e-04 - val_loss: 2.9397e-04
# Epoch 99/100
# 78/78 [==============================] - 5s 60ms/step - loss: 2.1641e-04 - val_loss: 4.0388e-04
# Epoch 100/100
# 78/78 [==============================] - 5s 59ms/step - loss: 2.1184e-04 - val_loss: 2.4569e-04
